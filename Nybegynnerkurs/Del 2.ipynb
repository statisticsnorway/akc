# %% [markdown]
# # Nybegynnerseminar del 2

# %% [markdown]
# ### Dagens plan

# %% [markdown]
# #### - Repetisjon av forrige mandag - objekter!
# #### - Pandas dataframes (tabeller)
#     - Hva er pandas, og hva er en pakke?
#     - Hvordan lese inn data
#     - Hvordan se på data
#         - df.head(), df.tail(), df.sample(), df.value_counts(), df.info(), df.columns()
#     - Hvordan endre data
#         - Lage nye kolonner
#         - Slette kolonner
#         - Verdi-selektering med .loc[]
#
# #### - (litt) github
# #### - Veien videre/lekser!:)

# %%
#int
heltall = 1

#float

desimaltall = 1.0

# %%
#list

liste = [1,2,3,4]

#dictionary 

dictionary = {1:2, 2:3, 4:5}

# %%
# string

tekst = '123'

# %% [markdown]
# ### PANDAS

# %%
import pandas as pd

# %%
filsti = 'https://raw.githubusercontent.com/rashida048/Datasets/master/fifa.csv'
fifa = pd.read_csv(filsti)

# %%
tinyurl.com/fifadatassb

# %%
fifa.head(3)
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
#
#    height_cm  weight_kg  nationality  ... mentality_penalties  \
# 0        169         67    Argentina  ...                  76
# 1        185         80     Portugal  ...                  85
# 2        180         80  Netherlands  ...                  80
#
#   mentality_composure  defending_marking  defending_standing_tackle  \
# ...

# %%
fifa.tail(3)
# Out:
#        Unnamed: 0  sofifa_id  \
# 16152       16152     217591
# 16153       16153     222947
# 16154       16154     201197
#
#                                               player_url  short_name  \
# 16152  https://sofifa.com/player/217591/piotr-zemlo/1...    P. Żemło
# 16153  https://sofifa.com/player/222947/tom-davies/15...   T. Davies
# 16154  https://sofifa.com/player/201197/paul-tisdale/...  P. Tisdale
#
#           long_name  age         dob  height_cm  weight_kg nationality  ...  \
# 16152   Piotr Żemło   18  1995-07-10        190         76      Poland  ...
# 16153    Tom Davies   22  1992-04-18        180         70     England  ...
# 16154  Paul Tisdale   41  1973-01-14        175         72       Malta  ...
#
#       mentality_penalties mentality_composure  defending_marking  \
# 16152                  31                 NaN                 54
# 16153                  21                 NaN                 36
# ...

# %%
fifa.sample(3)
# Out:
#       Unnamed: 0  sofifa_id  \
# 5560        5560     220201
# 3213        3213     146695
# 2773        2773     177280
#
#                                              player_url      short_name  \
# 5560  https://sofifa.com/player/220201/ivan-ledezma/...      I. Ledezma
# 3213  https://sofifa.com/player/146695/leo-franco/15...       L. Franco
# 2773  https://sofifa.com/player/177280/tore-reginius...  T. Reginiussen
#
#                           long_name  age         dob  height_cm  weight_kg  \
# 5560  Iván Patricio Ledezma Ahumada   18  1995-07-19        170         68
# 3213         Leonardo Neoren Franco   37  1977-05-20        188         79
# 2773               Tore Reginiussen   28  1986-04-10        185         80
#
#      nationality  ... mentality_penalties mentality_composure  \
# 5560       Chile  ...                  40                 NaN
# 3213   Argentina  ...                  29                 NaN
# 2773      Norway  ...                  31                 NaN
#
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Data columns (total 81 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  16155 non-null  int64
#  1   sofifa_id                   16155 non-null  int64
#  2   player_url                  16155 non-null  object
#  3   short_name                  16155 non-null  object
#  4   long_name                   16155 non-null  object
#  5   age                         16155 non-null  int64
#  6   dob                         16155 non-null  object
#  7   height_cm                   16155 non-null  int64
#  8   weight_kg                   16155 non-null  int64
#  9   nationality                 16155 non-null  object
#  10  club_name                   15916 non-null  object
#  11  league_name                 15916 non-null  object
#  12  league_rank                 15916 non-null  float64
# ...

# %%
fifa.describe()
# Out:
#          Unnamed: 0      sofifa_id           age     height_cm     weight_kg  \
# count  16155.000000   16155.000000  16155.000000  16155.000000  16155.000000
# mean    8077.000000  189284.184525     24.776230    181.083627     75.474342
# std     4663.691135   39749.261554      4.625321      6.618974      6.891796
# min        0.000000       2.000000     16.000000    155.000000     50.000000
# 25%     4038.500000  178042.500000     21.000000    176.000000     70.000000
# 50%     8077.000000  200841.000000     24.000000    181.000000     75.000000
# 75%    12115.500000  214346.000000     28.000000    186.000000     80.000000
# max    16154.000000  225562.000000     44.000000    204.000000    110.000000
#
#         league_rank       overall     potential     value_eur       wage_eur  \
# count  15916.000000  16155.000000  16155.000000  1.615500e+04   16155.000000
# mean       1.378424     63.830393     68.350108  1.060882e+06   13056.453110
# ...

# %%
fifa.value_counts
# Out:
# <bound method DataFrame.value_counts of        Unnamed: 0  sofifa_id  \
# 0               0     158023
# 1               1      20801
# 2               2       9014
# 3               3      41236
# 4               4     167495
# ...           ...        ...
# 16150       16150     220806
# 16151       16151     225509
# 16152       16152     217591
# 16153       16153     222947
# 16154       16154     201197
#
#                                               player_url         short_name  \
# 0      https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2      https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3      https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4      https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                  ...                ...
# ...

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'sofifa_id', 'player_url', 'short_name', 'long_name',
#        'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'league_rank', 'overall', 'potential', 'value_eur',
#        'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
# ...

# %%
fifa[['short_name', 'long_name']]
# Out:
#               short_name                            long_name
# 0               L. Messi       Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2              A. Robben                         Arjen Robben
# 3         Z. Ibrahimović                   Zlatan Ibrahimović
# 4               M. Neuer                         Manuel Neuer
# ...                  ...                                  ...
# 16150          E. Redman                         Ellis Redman
# 16151         A. Collins                        Aaron Collins
# 16152           P. Żemło                          Piotr Żemło
# 16153          T. Davies                           Tom Davies
# 16154         P. Tisdale                         Paul Tisdale
#
# [16155 rows x 2 columns]

# %%
fifa['ny_variabel'] = None

# %%
fifa[['short_name', 'long_name', 'ny_variabel']]
# Out:
#               short_name                            long_name ny_variabel
# 0               L. Messi       Lionel Andrés Messi Cuccittini        None
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro        None
# 2              A. Robben                         Arjen Robben        None
# 3         Z. Ibrahimović                   Zlatan Ibrahimović        None
# 4               M. Neuer                         Manuel Neuer        None
# ...                  ...                                  ...         ...
# 16150          E. Redman                         Ellis Redman        None
# 16151         A. Collins                        Aaron Collins        None
# 16152           P. Żemło                          Piotr Żemło        None
# 16153          T. Davies                           Tom Davies        None
# 16154         P. Tisdale                         Paul Tisdale        None
#
# [16155 rows x 3 columns]

# %%
fifa['defending_samlet'] = fifa['defending_marking'] + fifa['defending_standing_tackle'] + fifa['defending_sliding_tackle']

# %%
fifa[['defending_samlet', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle']]
# Out:
#        defending_samlet  defending_marking  defending_standing_tackle  \
# 0                    66                 25                         21
# 1                    76                 22                         31
# 2                    81                 29                         26
# 3                    93                 25                         41
# 4                    75                 25                         25
# ...                 ...                ...                        ...
# 16150               113                 38                         40
# 16151                75                 25                         25
# 16152               157                 54                         52
# 16153               105                 36                         34
# 16154                90                 27                         34
#
#        defending_sliding_tackle
# 0                            20
# 1                            23
# ...

# %%
fifa.shape
# Out:
# (16155, 84)

# %%
fifa_trettiplus = fifa.loc[fifa['age']>30]

# %%
fifa_3 = fifa.loc[(fifa['age']>30) & (fifa['height_cm']<165)]

# %%
fifa['age']
# Out:
# 0        27
# 1        29
# 2        30
# 3        32
# 4        28
#          ..
# 16150    17
# 16151    17
# 16152    18
# 16153    22
# 16154    41
# Name: age, Length: 16155, dtype: int64

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'sofifa_id', 'player_url', 'short_name', 'long_name',
#        'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'league_rank', 'overall', 'potential', 'value_eur',
#        'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
# ...

# %%
import pandas as pd

# %%
fifa_filsti = 'https://raw.githubusercontent.com/rashida048/Datasets/master/fifa.csv'
fifa = pd.read_csv(fifa_filsti)
fifa

# %%
cars_filsti = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv'

# %%
cars = pd.read_csv(cars_filsti)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
occupation_filsti = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %%
users = pd.read_csv(occupation_filsti, sep='|')

# %%
users
# Out:
#     user_id|age|gender|occupation|zip_code
# 0                  1|24|M|technician|85711
# 1                       2|53|F|other|94043
# 2                      3|23|M|writer|32067
# 3                  4|24|M|technician|43537
# 4                       5|33|F|other|15213
# ..                                     ...
# 938                 939|26|F|student|33319
# 939           940|32|M|administrator|02215
# 940                 941|20|M|student|97229
# 941               942|48|F|librarian|78209
# 942                 943|22|M|student|77841
#
# [943 rows x 1 columns]
