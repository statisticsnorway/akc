# %% [markdown]
# # Nybegynnerseminar del 2

# %% [markdown]
# ### Dagens plan

# %% [markdown]
# #### - Repetisjon av forrige mandag - objekter!
# #### - Pandas dataframes (tabeller)
#     - Hva er pandas, og hva er en pakke?
#     - Hvordan lese inn data
#     - Hvordan se på data
#         - df.head(), df.tail(), df.sample(), df.value_counts(), df.info(), df.columns()
#     - Hvordan endre data
#         - Lage nye kolonner
#         - Slette kolonner
#         - Verdi-selektering med .loc[]
#
# #### - (litt) github
# #### - Veien videre/lekser!:)

# %%
import pandas as pd

# %%
cars_filsti = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv'

# %%
cars = pd.read_csv(cars_filsti)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
occupation_filsti = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'

# %%
users = pd.read_csv(occupation_filsti, sep='|')

# %%
users
# Out:
#     user_id|age|gender|occupation|zip_code
# 0                  1|24|M|technician|85711
# 1                       2|53|F|other|94043
# 2                      3|23|M|writer|32067
# 3                  4|24|M|technician|43537
# 4                       5|33|F|other|15213
# ..                                     ...
# 938                 939|26|F|student|33319
# 939           940|32|M|administrator|02215
# 940                 941|20|M|student|97229
# 941               942|48|F|librarian|78209
# 942                 943|22|M|student|77841
#
# [943 rows x 1 columns]
